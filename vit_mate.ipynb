# %%
# !wget -O mini.sh https://repo.anaconda.com/miniconda/Miniconda3-py39_4.9.2-Linux-x86_64.sh
# !chmod +x mini.sh
# !bash ./mini.sh -b -f -p /usr/local
# !conda install -q -y jupyter
# !conda install -q -y google-colab -c conda-forge
# !python -m ipykernel install --name "py39" --use
# !pip install pytorch-lightning ipdb torchvision matplotlib transformers[torch]
# Out:
# --2022-09-15 18:08:36--  https://repo.anaconda.com/miniconda/Miniconda3-py39_4.9.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61451533 (59M) [application/x-sh]
# Saving to: ‘mini.sh’
#
# mini.sh             100%[===================>]  58.60M   328MB/s    in 0.2s
#
# 2022-09-15 18:08:36 (328 MB/s) - ‘mini.sh’ saved [61451533/61451533]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# failed with initial frozen solve. Retrying with flexible solve.
# \
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
if os.getcwd() != "/content/drive/MyDrive/":
  os.chdir('/content/drive/MyDrive')
os.system("rm -rf yerbamate")
if not os.path.exists('yerbamate'):
  # !git clone -b lightning https://github.com/ilex-paraguariensis/yerbamate
os.chdir('yerbamate')
# !git stash
# !git pull -f
# !python install.py
os.chdir('..')
if not os.path.exists('cifar-classification'):
  # !git clone https://github.com/lrhm/cifar-classification.git
os.chdir('cifar-classification')
# !git pull
# !pip install -r project/requirements.txt
# Out:
# Cloning into 'yerbamate'...
# remote: Enumerating objects: 828, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 828 (delta 6), reused 0 (delta 0), pack-reused 820
# Receiving objects: 100% (828/828), 15.50 MiB | 17.89 MiB/s, done.
# Resolving deltas: 100% (490/490), done.
# Already up to date.
# python: can't open file '/content/drive/MyDrive/yerbamate/rm': [Errno 2] No such file or directory
# running sdist
# running egg_info
# writing ymdl.egg-info/PKG-INFO
# writing dependency_links to ymdl.egg-info/dependency_links.txt
# writing top-level names to ymdl.egg-info/top_level.txt
# ...
# reading manifest file 'ymdl.egg-info/SOURCES.txt'
# writing manifest file 'ymdl.egg-info/SOURCES.txt'
# running check
# creating ymdl-0.2.5
# creating ymdl-0.2.5/src
# creating ymdl-0.2.5/mate
# creating ymdl-0.2.5/yerbamate
# creating ymdl-0.2.5/ymdl.egg-info
# copying files to ymdl-0.2.5...
# copying README.md -> ymdl-0.2.5
# ...

# %%
# select and train a model

# !mate train vit vanilla
# !mate train vit small_datasets
# !mate train vit distill
# !mate train vit crossformer

# fine tuning imagenet trained resnet for cifar10
# !mate restart resnet fine_tune --data.params.batch_size=256
# Out:
# Restarting model resnet with parameters: fine_tune.json
# {
#     "pytorch_lightning_module": {
#         "module": "trainers.base_classification",
#         "class": "LightningClassificationModule",
#         "params": {
#             "classifier": {
#                 "module": "modules.resnet.fine_tune",
#                 "class": "ResNetTuneModel",
#                 "params": {
#                     "num_classes": 10,
#                     "resnet": {
#                         "module": "torchvision.models",
#                         "class": "resnet18",
#                         "params": {
#                             "pretrained": true
#                         }
#                     }
#                 }
#             }
#         }
#     },
#     "optimizers": {
#         "classifier": {
#             "optimizer": {
#                 "module": "torch.optim",
#                 "class": "Adam",
#                 "params": {
#                     "lr": 0.0004,
# ...

# %%
# Out:
# Fri Jul  8 03:09:39 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
